# %%
import pandas as pd

# %%
homes = pd.read_csv('./data/home/listing_ny_port-washington_20210302.csv')

# %%
# Out:
#      Unnamed: 0      address_street         address_city_state  listed_price  \
# 0             0         19 Irma Ave  Port Washington, NY 11050        719000
# 1             1         38 Davis Rd  Port Washington, NY 11050        989000
# 2             2     86 Highland Ave  Port Washington, NY 11050        869000
# 3             3  57 Harbor Hills Dr  Port Washington, NY 11050        788000
# 4             4          2 South St  Port Washington, NY 11050        559900
# ..          ...                 ...                        ...           ...
# 140         140         160 8th Ave        Sea Cliff, NY 11579       1129000
# 141         141        7 Aspen Gate        Manhasset, NY 11030       4350000
# 142         142      161 Bayview Rd        Manhasset, NY 11030       3998000
# 143         143      9 Brentwood Ln       Great Neck, NY 11023       1648000
# 144         144     122 Plymouth Ct        Manhasset, NY 11030       3350000
#
# ...
